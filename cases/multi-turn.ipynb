# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent
from langchain.messages import SystemMessage, HumanMessage
from langgraph.checkpoint.memory import InMemorySaver
import uuid

load_dotenv()

model = init_chat_model(
    model="deepseek-chat"
)

agent = create_agent(
    model=model,
    system_prompt=SystemMessage("你是一个全能助手！"),
    checkpointer=InMemorySaver()
)

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

response1 = agent.invoke(
    {"messages": [HumanMessage("你好，我是小明")]},
    config=config
)

response2 = agent.invoke(
    {"messages": [HumanMessage("我叫什么名字")]},
    config=config
)

# %%
print(response1)

for message in response1["messages"]:
    message.pretty_print()
# Out:
# {'messages': [HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={}, id='960fac01-9c11-4356-99ca-107d5a307f30'), AIMessage(content='你好，小明！很高兴认识你！有什么我可以帮助你的吗？无论是学习、生活还是其他问题，我都很乐意为你提供帮助。😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 14, 'total_tokens': 45, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache', 'id': 'f2061439-ac2b-45b3-8339-56fa8a884081', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d011e-6790-7203-ac83-a0f7eb2622ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 31, 'total_tokens': 45, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# ================================ Human Message =================================
#
# 你好，我是小明
# ================================== Ai Message ==================================
#
# 你好，小明！很高兴认识你！有什么我可以帮助你的吗？无论是学习、生活还是其他问题，我都很乐意为你提供帮助。😊

# %%
print(response2)

for message in response2["messages"]:
    message.pretty_print()
# Out:
# {'messages': [HumanMessage(content='你好，我是小明', additional_kwargs={}, response_metadata={}, id='960fac01-9c11-4356-99ca-107d5a307f30'), AIMessage(content='你好，小明！很高兴认识你！有什么我可以帮助你的吗？无论是学习、生活还是其他问题，我都很乐意为你提供帮助。😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 14, 'total_tokens': 45, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache', 'id': 'f2061439-ac2b-45b3-8339-56fa8a884081', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d011e-6790-7203-ac83-a0f7eb2622ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 31, 'total_tokens': 45, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我叫什么名字', additional_kwargs={}, response_metadata={}, id='1cf8e7b2-b230-4cbd-a3bc-923a77abaaaa'), AIMessage(content='你刚才提到你的名字是“小明”。如果这不是你真实的姓名，或者你想让我用其他名字称呼你，请随时告诉我！ 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 52, 'total_tokens': 82, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 52}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache', 'id': '30518f92-8a8e-4409-98cf-1b8ba77afac1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d011e-6cce-7982-9336-bcd92c3d360d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 30, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# ================================ Human Message =================================
#
# 你好，我是小明
# ================================== Ai Message ==================================
#
# 你好，小明！很高兴认识你！有什么我可以帮助你的吗？无论是学习、生活还是其他问题，我都很乐意为你提供帮助。😊
# ================================ Human Message =================================
#
# 我叫什么名字
# ================================== Ai Message ==================================
#
# 你刚才提到你的名字是“小明”。如果这不是你真实的姓名，或者你想让我用其他名字称呼你，请随时告诉我！ 😊
